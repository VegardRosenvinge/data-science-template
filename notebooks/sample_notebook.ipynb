# %%
import pandas as pd

# %%
data1 = pd.read_csv('/home/touvegros/data-science-template/data/trafikkdata_hourly_30552V444220.csv')
data2 = pd.read_csv('/home/touvegros/data-science-template/data/trafikkdata_hourly_67263V1811577.csv')
data3 = pd.read_csv('/home/touvegros/data-science-template/data/trafikkdata_hourly_73894V444221.csv')
data4 = pd.read_csv('/home/touvegros/data-science-template/data/trafikkdata_hourly_79854V625215.csv')
data5 = pd.read_csv('/home/touvegros/data-science-template/data/trafikkdata_hourly_87610V1811579.csv')

# %%
data1.describe()
# Out:
#        total.volumeNumbers.volume  total.volumeNumbers.volume[5.6,..)  \
# count                 8663.000000                         8663.000000
# mean                   491.984994                          107.409442
# std                    412.448139                           67.976619
# min                      7.000000                            1.000000
# 25%                    129.000000                           46.000000
# 50%                    447.000000                           96.000000
# 75%                    699.500000                          168.000000
# max                   2313.000000                          291.000000
#
#        total.volumeNumbers.volume[5.6,7.6)  \
# count                          8663.000000
# mean                             19.143368
# std                              14.930501
# min                               0.000000
# 25%                               6.000000
# 50%                              15.000000
# 75%                              29.000000
# max                              82.000000
#
#        total.volumeNumbers.volume[7.6,12.5)  \
# count                           8663.000000
# mean                              27.080919
# std                               20.787238
# min                                0.000000
# 25%                                9.000000
# 50%                               24.000000
# 75%                               41.000000
# max                              117.000000
#
#        total.volumeNumbers.volume[12.5,16.0)  \
# count                            8663.000000
# mean                               14.391204
# std                                 9.928846
# min                                 0.000000
# 25%                                 6.000000
# 50%                                12.000000
# 75%                                21.000000
# max                               107.000000
#
#        total.volumeNumbers.volume[16.0,24.0)  \
# count                            8663.000000
# mean                               44.794875
# std                                31.443492
# min                                 0.000000
# 25%                                18.000000
# 50%                                37.000000
# 75%                                72.000000
# max                               146.000000
#
#        total.volumeNumbers.volume[24.0,..)
# count                          8663.000000
# mean                              1.999077
# std                               2.061063
# min                               0.000000
# 25%                               0.000000
# 50%                               1.000000
# 75%                               3.000000
# max                              13.000000

# %%
data2.describe()
# Out:
#        total.volumeNumbers.volume  total.volumeNumbers.volume[5.6,..)  \
# count                 5987.000000                         5987.000000
# mean                   489.578921                          114.772006
# std                    374.792939                           76.558233
# min                      0.000000                            0.000000
# 25%                    133.000000                           46.000000
# 50%                    485.000000                          101.000000
# 75%                    745.000000                          184.000000
# max                   1916.000000                          308.000000
#
#        total.volumeNumbers.volume[5.6,7.6)  \
# count                          5987.000000
# mean                             21.665108
# std                              16.786684
# min                               0.000000
# 25%                               7.000000
# 50%                              18.000000
# 75%                              35.000000
# max                              78.000000
#
#        total.volumeNumbers.volume[7.6,12.5)  \
# count                           5987.000000
# mean                              30.527810
# std                               23.120012
# min                                0.000000
# 25%                                9.000000
# 50%                               26.000000
# 75%                               49.000000
# max                              118.000000
#
#        total.volumeNumbers.volume[12.5,16.0)  \
# count                            5987.000000
# mean                               17.393519
# std                                12.360473
# min                                 0.000000
# 25%                                 7.000000
# 50%                                14.000000
# 75%                                26.000000
# max                                69.000000
#
#        total.volumeNumbers.volume[16.0,24.0)  \
# count                            5987.000000
# mean                               43.459162
# std                                31.458846
# min                                 0.000000
# 25%                                16.000000
# 50%                                36.000000
# 75%                                70.000000
# max                               132.000000
#
#        total.volumeNumbers.volume[24.0,..)
# count                          5987.000000
# mean                              1.726407
# std                               1.792896
# min                               0.000000
# 25%                               0.000000
# 50%                               1.000000
# 75%                               3.000000
# max                              12.000000

# %%
data3.describe()

# %%
data4.describe()

# %%
data4.describe()
